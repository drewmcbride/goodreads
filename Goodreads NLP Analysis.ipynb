# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.pipeline import make_pipeline

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.base import TransformerMixin
    
from joblib import dump

# %%
desc_df = pd.read_csv("book_data_cleaned.csv", encoding="L1")
desc_df.head()
# Out:
#    Unnamed: 0                                       book_authors  \
# 0           0                                    Suzanne Collins
# 1           1                        J.K. Rowling|Mary GrandPrÃ©
# 2           2                                         Harper Lee
# 3           3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4           4                                    Stephenie Meyer
#
#                                            book_desc    book_isbn book_pages  \
# 0  Winning will make you famous. Losing means cer...  9.78044E+12  374 pages
# 1  There is a door at the end of a silent corrido...  9.78044E+12  870 pages
# 2  The unforgettable novel of a childhood in a sl...  9.78006E+12  324 pages
# 3  Â«Ã cosa ormai risaputa che a uno scapolo in ...  9.78068E+12  279 pages
# 4  About three things I was absolutely positive.F...  9.78032E+12  498 pages
#
#    book_rating  book_rating_count  book_review_count  \
# 0         4.33            5519135             160706
# 1         4.48            2041594              33264
# 2         4.27            3745197              79450
# 3         4.25            2453620              54322
# 4         3.58            4281268              97991
#
#                                   book_title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                               genres  \
# 0  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                        Fantasy|Young Adult|Fiction
# 2  Classics|Fiction|Historical|Historical Fiction...
# 3                           Classics|Fiction|Romance
# 4  Young Adult|Fantasy|Romance|Paranormal|Vampire...
#
#                                            image_url  pages
# 0  https://images.gr-assets.com/books/1447303603l...    374
# 1  https://images.gr-assets.com/books/1255614970l...    870
# 2  https://images.gr-assets.com/books/1361975680l...    324
# 3  https://images.gr-assets.com/books/1320399351l...    279
# 4  https://images.gr-assets.com/books/1361039443l...    498

# %%
desc_df.dtypes
# Out:
# Unnamed: 0             int64
# book_authors          object
# book_desc             object
# book_isbn             object
# book_pages            object
# book_rating          float64
# book_rating_count      int64
# book_review_count      int64
# book_title            object
# genres                object
# image_url             object
# pages                  int64
# dtype: object

# %%
desc_df['good_books'] = np.where(desc_df['book_rating']>=4, 'good', 'bad')

# %%
del desc_df['Unnamed: 0']

# %%
desc_df.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                        J.K. Rowling|Mary GrandPrÃ©
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc    book_isbn book_pages  \
# 0  Winning will make you famous. Losing means cer...  9.78044E+12  374 pages
# 1  There is a door at the end of a silent corrido...  9.78044E+12  870 pages
# 2  The unforgettable novel of a childhood in a sl...  9.78006E+12  324 pages
# 3  Â«Ã cosa ormai risaputa che a uno scapolo in ...  9.78068E+12  279 pages
# 4  About three things I was absolutely positive.F...  9.78032E+12  498 pages
#
#    book_rating  book_rating_count  book_review_count  \
# 0         4.33            5519135             160706
# 1         4.48            2041594              33264
# 2         4.27            3745197              79450
# 3         4.25            2453620              54322
# 4         3.58            4281268              97991
#
#                                   book_title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                               genres  \
# 0  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                        Fantasy|Young Adult|Fiction
# 2  Classics|Fiction|Historical|Historical Fiction...
# 3                           Classics|Fiction|Romance
# 4  Young Adult|Fantasy|Romance|Paranormal|Vampire...
#
#                                            image_url  pages good_books
# 0  https://images.gr-assets.com/books/1447303603l...    374       good
# 1  https://images.gr-assets.com/books/1255614970l...    870       good
# 2  https://images.gr-assets.com/books/1361975680l...    324       good
# 3  https://images.gr-assets.com/books/1320399351l...    279       good
# 4  https://images.gr-assets.com/books/1361039443l...    498        bad

# %%
desc_df.describe()
# Out:
#         book_rating  book_rating_count  book_review_count         pages
# count  51779.000000       5.177900e+04       51779.000000  51779.000000
# mean       4.014720       4.507358e+04        2083.296800    337.662836
# std        0.343791       2.166495e+05        7752.234528    259.533005
# min        0.000000       0.000000e+00           0.000000      0.000000
# 25%        3.820000       4.920000e+02          41.000000    216.000000
# 50%        4.020000       3.095000e+03         207.000000    310.000000
# 75%        4.210000       1.367500e+04         873.000000    400.000000
# max        5.000000       5.588580e+06      160776.000000  14777.000000

# %%
X = desc_df['book_desc'].fillna(' ').values
y = desc_df['good_books'].values

# %%
# v = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=345)

# %%
y_train
# Out:
# array(['good', 'bad', 'good', ..., 'bad', 'bad', 'good'], dtype=object)

# %%
nb = make_pipeline(
    CountVectorizer(binary=True),
    TfidfTransformer(),
#     LogisticRegression()
#     RandomForestClassifier(),
    MultinomialNB()
)

# %%
nb.fit(X_train, y_train);

# %%
y_pred = nb.predict(X_test)

# %%
y_pred
# Out:
# array(['good', 'good', 'good', ..., 'good', 'good', 'good'], dtype='<U4')

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.69      0.22      0.33      5932
#         good       0.58      0.92      0.71      7013
#
#     accuracy                           0.60     12945
#    macro avg       0.64      0.57      0.52     12945
# weighted avg       0.63      0.60      0.54     12945

# %%
nb.predict(X)
# Out:
# array(['good', 'good', 'good', ..., 'good', 'good', 'good'], dtype='<U4')

# %%
desc_df['pred_books'] = nb.predict(X)
desc_df.head(15)
# Out:
#                                          book_authors  \
# 0                                     Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPrÃ©
# 2                                          Harper Lee
# 3   Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                     Stephenie Meyer
# 5                                        Markus Zusak
# 6                           C.S. Lewis|Pauline Baynes
# 7                                       George Orwell
# 8                                   Margaret Mitchell
# 9                                      J.R.R. Tolkien
# 10                                         John Green
# 11                                      Douglas Adams
# 12                                   Shel Silverstein
# 13  Emily BrontÃ«|Richard J. Dunn|David Timson|Cha...
# 14                                          Dan Brown
#
#                                             book_desc    book_isbn  \
# 0   Winning will make you famous. Losing means cer...  9.78044E+12
# 1   There is a door at the end of a silent corrido...  9.78044E+12
# 2   The unforgettable novel of a childhood in a sl...  9.78006E+12
# 3   Â«Ã cosa ormai risaputa che a uno scapolo in ...  9.78068E+12
# 4   About three things I was absolutely positive.F...  9.78032E+12
# 5   Trying to make sense of the horrors of World W...  9.78038E+12
# 6   Journeys to the end of the world, fantastic cr...  9.78007E+12
# 7   Ù
# Ø²Ø±Ø¹Ø© Ø§ÙØ­ÙÙØ§ÙØ§Øª ÙÙ Ø±Ø§Ø¦Ø¹Ø© ...  9.78045E+12
# 8   Gone with the Wind is a novel written by Marga...  9.78045E+12
# 9   ÙØ¬Ø²Ø¡ Ø§ÙØ«Ø§ÙØ« Ù
# Ù Ù
# ÙØ­Ù
# Ø© Ø¬ÙÙ Ø...  9.78035E+12
# 10  Despite the tumor-shrinking medical miracle th...  9.78053E+12
# 11  Seconds before the Earth is demolished to make...  9.78035E+12
# 12  "Once there was a tree...and she loved a littl...  9.78006E+12
# 13  You can find the redesigned cover of this edit...  9.78039E+12
# 14  An ingenious code hidden in the works of Leona...  9.78031E+12
#
#     book_pages  book_rating  book_rating_count  book_review_count  \
# 0    374 pages         4.33            5519135             160706
# 1    870 pages         4.48            2041594              33264
# 2    324 pages         4.27            3745197              79450
# 3    279 pages         4.25            2453620              54322
# 4    498 pages         3.58            4281268              97991
# 5    552 pages         4.36            1485632             100821
# 6    767 pages         4.25             437829               9439
# 7    122 pages         3.90            2235084              42156
# 8   1037 pages         4.29             969181              17452
# 9   1728 pages         4.59              99793               1652
# 10   313 pages         4.24            2881648             147270
# 11   193 pages         4.21            1155911              23919
# 12    64 pages         4.37             789681              15694
# 13   464 pages         3.84            1121100              29400
# 14   481 pages         3.81            1668594              43699
#
#                                            book_title  \
# 0                                    The Hunger Games
# 1           Harry Potter and the Order of the Phoenix
# 2                               To Kill a Mockingbird
# 3                                 Pride and Prejudice
# 4                                            Twilight
# 5                                      The Book Thief
# 6                            The Chronicles of Narnia
# 7                                         Animal Farm
# 8                                  Gone with the Wind
# 9   J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 10                             The Fault in Our Stars
# 11               The Hitchhiker's Guide to the Galaxy
# 12                                    The Giving Tree
# 13                                  Wuthering Heights
# 14                                  The Da Vinci Code
#
#                                                genres  \
# 0   Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                         Fantasy|Young Adult|Fiction
# 2   Classics|Fiction|Historical|Historical Fiction...
# 3                            Classics|Fiction|Romance
# 4   Young Adult|Fantasy|Romance|Paranormal|Vampire...
# 5   Historical|Historical Fiction|Fiction|Young Adult
# 6      Fantasy|Classics|Fiction|Young Adult|Childrens
# 7   Classics|Fiction|Science Fiction|Dystopia|Fant...
# 8   Classics|Historical|Historical Fiction|Fiction...
# 9                            Fantasy|Fiction|Classics
# 10           Young Adult|Fiction|Romance|Contemporary
# 11     Science Fiction|Fiction|Humor|Fantasy|Classics
# 12  Childrens|Childrens|Picture Books|Classics|Fic...
# 13                Classics|Fiction|Romance|Literature
# 14                           Fiction|Mystery|Thriller
#
#                                             image_url  pages good_books  \
# 0   https://images.gr-assets.com/books/1447303603l...    374       good
# 1   https://images.gr-assets.com/books/1255614970l...    870       good
# 2   https://images.gr-assets.com/books/1361975680l...    324       good
# 3   https://images.gr-assets.com/books/1320399351l...    279       good
# 4   https://images.gr-assets.com/books/1361039443l...    498        bad
# 5   https://images.gr-assets.com/books/1522157426l...    552       good
# 6   https://images.gr-assets.com/books/1449868701l...    767       good
# 7   https://images.gr-assets.com/books/1424037542l...    122        bad
# 8   https://images.gr-assets.com/books/1328025229l...   1037       good
# 9   https://images.gr-assets.com/books/1346072396l...   1728       good
# 10  https://images.gr-assets.com/books/1360206420l...    313       good
# 11  https://images.gr-assets.com/books/1388282444l...    193       good
# 12  https://images.gr-assets.com/books/1174210942l...     64       good
# 13  https://images.gr-assets.com/books/1388212715l...    464        bad
# 14  https://images.gr-assets.com/books/1303252999l...    481        bad
#
#    pred_books
# 0        good
# 1        good
# 2        good
# 3         bad
# 4         bad
# 5        good
# 6        good
# 7         bad
# 8        good
# 9         bad
# 10       good
# 11       good
# 12       good
# 13       good
# 14        bad

# %%
dump(nb, "clf.joblib")
# Out:
# ['clf.joblib']
